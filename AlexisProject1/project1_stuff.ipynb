# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
# %matplotlib inline
import matplotlib.image as mpimg
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
sns.set_style("whitegrid")
plt.style.use('dark_background')

# %%
fr_df = pd.read_csv("fertility_2004-2013.csv")#, header=0)
fr_df.head()
# Out:
#            Country Name Country Code                      Region   2004  \
# 0                 Aruba          ABW   Latin America & Caribbean  1.786
# 1                Angola          AGO          Sub-Saharan Africa  6.704
# 2               Albania          ALB       Europe & Central Asia  2.004
# 3  United Arab Emirates          ARE  Middle East & North Africa  2.236
# 4             Argentina          ARG   Latin America & Caribbean  2.310
#
#     2005   2006   2007   2008   2009   2010   2011   2012   2013
# 0  1.769  1.754  1.739  1.726  1.713  1.701  1.690  1.681  1.673
# 1  6.657  6.598  6.523  6.434  6.331  6.218  6.099  5.979  5.863
# 2  1.919  1.849  1.796  1.761  1.744  1.741  1.748  1.760  1.771
# 3  2.149  2.071  2.004  1.948  1.903  1.868  1.841  1.820  1.801
# 4  2.286  2.268  2.254  2.241  2.228  2.215  2.201  2.188  2.175

# %%
sorted_fr_data=fr_df.groupby(['Region']).mean()
#sorted_fr_data=sorted_fr_data.drop('2003',1)
sorted_fr_data
# Out:
#                                 2004      2005      2006      2007      2008  \
# Region
# East Asia & Pacific         2.696652  2.663217  2.647870  2.638348  2.612087
# Europe & Central Asia       1.595793  1.597390  1.630122  1.661488  1.706244
# Latin America & Caribbean   2.599567  2.559700  2.522933  2.488700  2.456400
# Middle East & North Africa  2.831625  2.771625  2.725687  2.688250  2.660125
# North America               1.790750  1.798500  1.847100  1.889450  1.876400
# South Asia                  2.962571  2.876571  2.801286  2.734143  2.673000
# Sub-Saharan Africa          5.220475  5.166925  5.103475  5.047250  4.987525
#
#                                 2009      2010      2011      2012      2013
# Region
# East Asia & Pacific         2.576348  2.554304  2.526174  2.505696  2.466522
# Europe & Central Asia       1.700000  1.704439  1.675634  1.685732  1.681829
# Latin America & Caribbean   2.425733  2.396233  2.367967  2.340700  2.314600
# ...

# %%
years=sorted_fr_data.keys()
#region_one=plt.plot(years, sorted_fr_data.loc['Central Africa', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
#                                              color='sandybrown',marker='P',label='Central Africa')
#region_two=plt.plot(years, sorted_fr_data.loc['Dutch Caribbean', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
#                                              color='aqua', marker='o',label='Dutch Caribbean')
region_three=plt.plot(years, sorted_fr_data.loc['East Asia & Pacific', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
                                              color='orangered', marker='v',label='East Asia & Pacific')
region_four=plt.plot(years, sorted_fr_data.loc['Europe & Central Asia', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
                                              color='royalblue', marker='s',label='Europe & Central Asia')
region_five=plt.plot(years, sorted_fr_data.loc['Latin America & Caribbean', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
                                              color='yellow', marker='h',label='Latin America & Caribbean')
region_six=plt.plot(years, sorted_fr_data.loc['Middle East & North Africa', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
                                              color='orange', marker='D',label='Middle East & North Africa')
region_seven=plt.plot(years, sorted_fr_data.loc['North America', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
                                              color='red', marker='X',label='North America')
region_eight=plt.plot(years, sorted_fr_data.loc['South Asia', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
                                              color='magenta', marker='x',label='South Asia')
region_nine=plt.plot(years, sorted_fr_data.loc['Sub-Saharan Africa', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
                                              color='Springgreen', marker='8',label='Sub-Saharan Africa')
#region_ten=plt.plot(years, sorted_fr_data.loc['West Africa', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
#                                              color='chartreuse', marker='*',label='West Africa')
plt.legend(loc='upper center', bbox_to_anchor=(1.4, 0.9), shadow=True, ncol=1)
plt.grid=True
plt.title('Fertility Rates(2004-2013)')
plt.ylabel('Average Births per Woman')
plt.xlabel('Years')
plt.savefig('Fertility.png')
plt.show()

# %%
inc_df = pd.read_csv("income_2004-2013.csv")#, header=0)
inc_df.head().round(2)
# Out:
#            Country Name Country Code                      Region      2004  \
# 0                 Aruba          ABW   Latin America & Caribbean  19503.28
# 1                Angola          AGO          Sub-Saharan Africa    440.75
# 2               Albania          ALB       Europe & Central Asia   2232.47
# 3  United Arab Emirates          ARE  Middle East & North Africa  32307.05
# 4             Argentina          ARG   Latin America & Caribbean   3176.81
#
#        2005      2006      2007      2008      2009      2010      2011  \
# 0  16199.59  20567.53  19423.43  23229.61  21289.65  19741.15  19960.52
# 1    563.93    856.91    819.69    367.19    735.38   1108.34   1494.24
# 2   2500.86   2808.97   3334.00   3961.90   3622.33   3530.69   3853.17
# 3  33402.26  35940.37  36627.75  37339.64  27355.86  30537.82  34564.78
# 4   3794.10   4893.94   6111.50   7607.62   6956.12   8810.36  11008.52
#
#        2012      2013
# 0  21038.15  20841.49
# 1   1789.73   2113.87
# ...

# %%
sorted_inc_data=inc_df.groupby(['Region']).mean()
sorted_inc_data.round(2)
# Out:
#                                 2004      2005      2006      2007      2008  \
# Region
# East Asia & Pacific          6391.76   6919.22   7345.29   8238.99   8842.11
# Europe & Central Asia       16399.20  17523.48  18736.87  21827.73  23689.10
# Latin America & Caribbean    4439.69   4792.33   5410.72   5979.00   6742.75
# Middle East & North Africa   9297.06  10420.84  11927.66  13231.55  15230.16
# North America               30863.53  33589.95  36297.38  38472.30  39084.98
# South Asia                   1068.00   1093.28   1325.84   1453.88   1666.67
# Sub-Saharan Africa           1056.40   1144.46   1245.06   1344.23   1388.14
#
#                                 2009      2010      2011      2012      2013
# Region
# East Asia & Pacific          8150.98   9810.00  11299.15  11887.73  11945.58
# Europe & Central Asia       20547.97  21038.91  22897.74  21735.04  22643.65
# Latin America & Caribbean    6361.54   6910.84   7270.60   7702.96   7935.77
# ...

# %%
years=sorted_inc_data.keys()
#region_one=plt.plot(years, sorted_inc_data.loc['Central Africa', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
#                                              color='sandybrown',marker='P',label='Central Africa')
#region_two=plt.plot(years, sorted_inc_data.loc['Dutch Caribbean', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
#                                              color='aqua', marker='o',label='Dutch Caribbean')
region_three=plt.plot(years, sorted_inc_data.loc['East Asia & Pacific', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
                                              color='orangered', marker='v',label='East Asia & Pacific')
region_four=plt.plot(years, sorted_inc_data.loc['Europe & Central Asia', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
                                              color='royalblue', marker='s',label='Europe & Central Asia')
region_five=plt.plot(years, sorted_inc_data.loc['Latin America & Caribbean', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
                                              color='yellow', marker='h',label='Latin America & Caribbean')
region_six=plt.plot(years, sorted_inc_data.loc['Middle East & North Africa', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
                                              color='orange', marker='D',label='Middle East & North Africa')
region_seven=plt.plot(years, sorted_inc_data.loc['North America', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
                                              color='red', marker='X',label='North America')
region_eight=plt.plot(years, sorted_inc_data.loc['South Asia', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
                                              color='magenta', marker='x',label='South Asia')
region_nine=plt.plot(years, sorted_inc_data.loc['Sub-Saharan Africa', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
                                              color='Springgreen', marker='8',label='Sub-Saharan Africa')
#region_ten=plt.plot(years, sorted_inc_data.loc['West Africa', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
#                                             color='chartreuse', marker='*',label='West Africa')
plt.legend(loc='upper center', bbox_to_anchor=(1.4, 0.9), shadow=True, ncol=1)
plt.grid=True
plt.title('Income Rates(2004-2013)')
plt.ylabel('Average Income per Region')
plt.xlabel('Years')
plt.savefig('Income.png')
plt.show()

# %%
le_df = pd.read_csv("life_expectancy_2004-2013.csv")#, header=0)
le_df.head()
# Out:
#            Country Name Country Code                      Region       2004  \
# 0                 Aruba          ABW   Latin America & Caribbean  74.090854
# 1                Angola          AGO          Sub-Saharan Africa  48.003512
# 2               Albania          ALB       Europe & Central Asia  75.839000
# 3  United Arab Emirates          ARE  Middle East & North Africa  75.355732
# 4             Argentina          ARG   Latin America & Caribbean  74.557732
#
#         2005       2006       2007       2008       2009       2010  \
# 0  74.228073  74.375707  74.526244  74.674220  74.816146  74.952024
# 1  48.538805  49.007049  49.435732  49.847390  50.251024  50.654171
# 2  76.089390  76.290537  76.464854  76.632317  76.801878  76.978512
# 3  75.581951  75.800122  76.011220  76.214756  76.410707  76.598610
# 4  74.751659  74.941220  75.126902  75.308195  75.487098  75.663561
#
#         2011       2012       2013
# 0  75.080390  75.206756  75.332171
# ...

# %%
sorted_le_data=le_df.groupby(['Region']).mean()
sorted_le_data
# Out:
#                                  2004       2005       2006       2007  \
# Region
# East Asia & Pacific         71.071357  71.397485  71.702645  71.982123
# Europe & Central Asia       74.938737  75.081455  75.372006  75.584537
# Latin America & Caribbean   71.860538  72.102112  72.342537  72.580366
# Middle East & North Africa  72.836005  73.057343  73.311334  73.525800
# North America               78.740244  78.815854  79.115854  79.104451
# South Asia                  67.150415  67.603087  68.011282  68.388028
# Sub-Saharan Africa          53.440941  53.931548  54.495670  55.120012
#
#                                  2008       2009       2010       2011  \
# Region
# East Asia & Pacific         72.247742  72.524233  72.739801  72.953151
# Europe & Central Asia       75.894453  76.197789  76.452450  76.901206
# Latin America & Caribbean   72.815011  73.045137  73.270318  73.489860
# Middle East & North Africa  73.752438  73.976678  74.179732  74.343598
# ...

# %%
years=sorted_inc_data.keys()
#region_one=plt.plot(years, sorted_le_data.loc['Central Africa', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
#                                              color='sandybrown',marker='P',label='Central Africa')
#region_two=plt.plot(years, sorted_le_data.loc['Dutch Caribbean', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
#                                              color='aqua', marker='o',label='Dutch Caribbean')
region_three=plt.plot(years, sorted_le_data.loc['East Asia & Pacific', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
                                              color='orangered', marker='v',label='East Asia & Pacific')
region_four=plt.plot(years, sorted_le_data.loc['Europe & Central Asia', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
                                              color='royalblue', marker='s',label='Europe & Central Asia')
region_five=plt.plot(years, sorted_le_data.loc['Latin America & Caribbean', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
                                              color='yellow', marker='h',label='Latin America & Caribbean')
region_six=plt.plot(years, sorted_le_data.loc['Middle East & North Africa', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
                                              color='orange', marker='D',label='Middle East & North Africa')
region_seven=plt.plot(years, sorted_le_data.loc['North America', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
                                              color='red', marker='X',label='North America')
region_eight=plt.plot(years, sorted_le_data.loc['South Asia', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
                                              color='magenta', marker='x',label='South Asia')
region_nine=plt.plot(years, sorted_le_data.loc['Sub-Saharan Africa', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
                                              color='Springgreen', marker='8',label='Sub-Saharan Africa')
#region_ten=plt.plot(years, sorted_le_data.loc['West Africa', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
#                                              color='chartreuse', marker='*',label='West Africa')
plt.legend(loc='upper center', bbox_to_anchor=(1.4, 0.9), shadow=True, ncol=1)
plt.grid=True
plt.title('Life Expectancy (2004-2013)')
plt.ylabel('Average Life Expectancy at Birth')
plt.xlabel('Years')
plt.savefig('Life Expectancy.png')
plt.show()

# %%
pop_df = pd.read_csv("population_2004-2013.csv")#, header=0)
pop_df.head()
# Out:
#            Country Name Country Code                      Region      2004  \
# 0                 Aruba          ABW   Latin America & Caribbean     98742
# 1                Angola          AGO          Sub-Saharan Africa  17295500
# 2               Albania          ALB       Europe & Central Asia   3026939
# 3  United Arab Emirates          ARE  Middle East & North Africa   3975945
# 4             Argentina          ARG   Latin America & Caribbean  38728778
#
#        2005      2006      2007      2008      2009      2010      2011  \
# 0    100031    100830    101218    101342    101416    101597    101936
# 1  17912942  18541467  19183907  19842251  20520103  21219954  21942296
# 2   3011487   2992547   2970017   2947314   2927519   2913021   2904780
# 3   4481976   5171255   6010100   6900142   7705423   8329453   8734722
# 4  39145491  39558750  39969903  40381860  40798641  41222875  41655616
#
#        2012      2013
# 0    102393    102921
# 1  22685632  23448202
# ...

# %%
sorted_pop_data=pop_df.groupby(['Region']).mean()
sorted_pop_data
# Out:
#                                     2004          2005          2006  \
# Region
# East Asia & Pacific         8.953439e+07  9.020750e+07  9.086598e+07
# Europe & Central Asia       2.055726e+07  2.062128e+07  2.068569e+07
# Latin America & Caribbean   1.836694e+07  1.860904e+07  1.885081e+07
# Middle East & North Africa  1.822150e+07  1.856763e+07  1.892983e+07
# North America               1.624001e+08  1.639143e+08  1.654752e+08
# South Asia                  2.090141e+08  2.123885e+08  2.157259e+08
# Sub-Saharan Africa          1.678665e+07  1.724478e+07  1.771937e+07
#
#                                     2007          2008          2009  \
# Region
# East Asia & Pacific         9.149296e+07  9.212864e+07  9.274852e+07
# Europe & Central Asia       2.075630e+07  2.083826e+07  2.092422e+07
# Latin America & Caribbean   1.909187e+07  1.933195e+07  1.957056e+07
# Middle East & North Africa  1.930634e+07  1.969703e+07  2.010382e+07
# ...

# %%
years=sorted_inc_data.keys()
#plt.ylim(-0, 3,.25)
#region_one=plt.plot(years, sorted_pop_data.loc['Central Africa', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
#                                              color='sandybrown',marker='P',label='Central Africa')
#region_two=plt.plot(years, sorted_pop_data.loc['Dutch Caribbean', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
#                                              color='aqua', marker='o',label='Dutch Caribbean')
region_three=plt.plot(years, sorted_pop_data.loc['East Asia & Pacific', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
                                              color='orangered', marker='v',label='East Asia & Pacific')
region_four=plt.plot(years, sorted_pop_data.loc['Europe & Central Asia', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
                                              color='royalblue', marker='s',label='Europe & Central Asia')
region_five=plt.plot(years, sorted_pop_data.loc['Latin America & Caribbean', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
                                              color='yellow', marker='h',label='Latin America & Caribbean')
region_six=plt.plot(years, sorted_pop_data.loc['Middle East & North Africa', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
                                              color='orange', marker='D',label='Middle East & North Africa')
region_seven=plt.plot(years, sorted_pop_data.loc['North America', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
                                              color='red', marker='X',label='North America')
region_eight=plt.plot(years, sorted_pop_data.loc['South Asia', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
                                              color='magenta', marker='x',label='South Asia')
region_nine=plt.plot(years, sorted_pop_data.loc['Sub-Saharan Africa', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
                                              color='Springgreen', marker='8',label='Sub-Saharan Africa')
#region_ten=plt.plot(years, sorted_pop_data.loc['West Africa', ['2004','2005','2006','2007','2008','2009','2010','2011','2012','2013']],
#                                              color='chartreuse', marker='*',label='West Africa')
plt.legend(loc='upper center', bbox_to_anchor=(1.4, 0.9), shadow=True, ncol=1)
plt.grid=True
plt.title('Population (2004-2013)')
plt.ylabel('Average Popuation')
plt.xlabel('Years')
plt.savefig('Population.png')
plt.show()
