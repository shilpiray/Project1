# %%
import pandas as pd

# %%
fertility = pd.read_csv("fertility_2003-2013.csv")

# %%
a.head()
# Out:
#   Country Name Country Code                     Region           IncomeGroup  \
# 0        Aruba          ABW  Latin America & Caribbean  High income: nonOECD
# 1  Afghanistan          AFG                 South Asia            Low income
# 2       Angola          AGO         Sub-Saharan Africa   Upper middle income
# 3      Albania          ALB      Europe & Central Asia   Upper middle income
# 4      Andorra          AND      Europe & Central Asia  High income: nonOECD
#
#                                         SpecialNotes
# 0  SNA data for 2000-2011 are updated from offici...
# 1  Fiscal year end: March 20; reporting period fo...
# 2  April 2013 database update: Based on IMF data,...
# 3                                                NaN
# 4                                                NaN

# %%
income = pd.read_csv("income_2003-2013.csv")
income.head()
# Out:
#   Country Name Country Code                    Region   \
# 0        Aruba          ABW  Latin America & Caribbean
# 1      Andorra          AND      Europe & Central Asia
# 2  Afghanistan          AFG                 South Asia
# 3       Angola          AGO         Sub-Saharan Africa
# 4      Albania          ALB      Europe & Central Asia
#
#                                       Indicator Name          2003  \
# 0  Adjusted net national income per capita (curre...  18140.298180
# 1  Adjusted net national income per capita (curre...      0.000000
# 2  Adjusted net national income per capita (curre...      0.000000
# 3  Adjusted net national income per capita (curre...    437.003981
# 4  Adjusted net national income per capita (curre...   1743.114101
#
#            2004          2005          2006          2007          2008  \
# 0  19503.280280  16199.594850  20567.526980  19423.428950  23229.613610
# 1      0.000000      0.000000      0.000000      0.000000      0.000000
# ...
